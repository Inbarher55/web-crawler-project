# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urlparse, urljoin

def clean_url(url, base_url):
    parsed_url = urlparse(url)
    clean_url = parsed_url._replace(fragment="").geturl()  # הסרת עוגנים (#)
    if not clean_url.startswith('http'):
        clean_url = urljoin(base_url, clean_url)  # הפיכת כתובת יחסית למוחלטת
    return clean_url

def web_crawler(base_url):
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    data = []
    seen_urls = set()

    page_title = soup.title.string if soup.title else 'No Title'
    data.append({
        'שם דף': page_title,
        'כתובת עמוד': base_url,
        'תוכן עמוד': soup.get_text()
    })
    seen_urls.add(base_url)

    links = soup.find_all('a', href=True)
    
    for link in links:
        url = clean_url(link['href'], base_url)
        if url not in seen_urls:
            try:
                print(f"Processing: {url}")
                link_response = requests.get(url)
                link_soup = BeautifulSoup(link_response.text, 'html.parser')
                link_title = link_soup.title.string if link_soup.title else 'No Title'
                data.append({
                    'שם דף': link_title,
                    'כתובת עמוד': url,
                    'תוכן עמוד': link_soup.get_text()
                })
                seen_urls.add(url)
            except requests.exceptions.RequestException as e:
                print(f"Error accessing {url}: {e}")

    return data

def save_to_excel(data, filename='web_crawl_output_ynet.xlsx'):
    df = pd.DataFrame(data)
    df.to_excel(filename, index=False)

# כתובת האתר הראשי של Ynet
base_url = 'https://www.ynet.co.il/'

# ביצוע זחילה ושמירת התוצאות
data = web_crawler(base_url)
save_to_excel(data)

print(f"Data successfully saved to 'web_crawl_output_ynet.xlsx'")
# Out:
# Processing: https://www.ynet.co.il/news/category/184
# Processing: https://www.ynet.co.il/redmail
# Processing: https://www.ynet.co.il/home/0,7340,L-201,00.html
# Processing: https://www.ynet.co.il/home/0,7340,L-8,00.html
# Processing: javascript:YitPaywall.openLoginPopUp(false,{ redirect_to_plus : true })
# Error accessing javascript:YitPaywall.openLoginPopUp(false,{ redirect_to_plus : true }): No connection adapters were found for 'javascript:YitPaywall.openLoginPopUp(false,{ redirect_to_plus : true })'
# Processing: https://premium.ynet.co.il/Web/Register
# Processing: https://www.ynet.co.il/plus
# Processing: https://www.ynet.co.il/news
# Processing: https://www.ynet.co.il/news/247
# Processing: https://www.ynet.co.il/radio
# Processing: https://www.ynet.co.il/economy
# Processing: https://www.ynet.co.il/sport
# Processing: https://www.ynet.co.il/entertainment
# Processing: https://pplus.ynet.co.il/homepage
# Processing: https://www.ynet.co.il/health
# Processing: https://www.ynet.co.il/wheels
# Processing: https://www.ynet.co.il/digital
# Processing: https://www.ynet.co.il/laisha
# Processing: https://www.ynet.co.il/food
# Processing: javascript:void(0);
# Error accessing javascript:void(0);: No connection adapters were found for 'javascript:void(0);'
# Processing: https://www.yedioth.co.il/?externalurl=true
# Processing: https://www.ynet.co.il/news/category/194
# Processing: https://weather.ynet.co.il/
# Processing: https://www.ynet.co.il/economy/category/5363
# Processing: https://www.ynet.co.il/economy/category/8315
# Processing: https://www.ynet.co.il/vacation
# Processing: https://www.ynet.co.il/dating
# Processing: https://www.ynet.co.il/menta
# Processing: https://www.ynet.co.il/judaism
# Processing: https://www.ynet.co.il/parents
# Processing: https://w.ynet.co.il/product/ynetcreativestudio/?externalurl=true
# Processing: https://www.ynet.co.il/environment-science
# Processing: https://www.ynet.co.il/activism
# Processing: https://www.ynet.co.il/fashion
# Processing: https://www.ynet.co.il/architecture
# Processing: https://p.ynet.co.il/ynet-original/?externalurl=true
# Processing: https://www.ynet.co.il/weather
# Processing: https://www.ynet.co.il/category/40552
# Processing: https://z.ynet.co.il/mshort/commerce/2018/musafimspecial
# Processing: https://www.alljobs.co.il/?utm_source=ynet&utm_medium=cooperation&utm_campaign=Banana
# Processing: https://www.ynet.co.il/activism/category/36572
# Processing: https://www.ynet.co.il/capital
# Processing: https://www.calcalist.co.il/home/0,7340,L-8,00.html
# Processing: https://www.ynetnews.com/category/3083
# Processing: https://www.ynetespanol.com/
# Processing: https://www.vesty.co.il/
# Processing: https://www.mynet.co.il/
# Processing: https://www.yad2.co.il/?utm_source=ynet&utm_medium=link_footer
# Processing: https://www.ynet.co.il/games
# Processing: https://www.ynet.co.il/article/rkskixybt
# Processing: https://www.ynet.co.il/article/h1oypwysn
# Processing: https://www.ynet.co.il/article/bkswwa3sn
# Processing: https://www.ynet.co.il/home/0,7340,L-4080,00.html
# Processing: https://twitter.com/ynetalerts?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor
# Processing: https://www.facebook.com/ynetnews/
# Processing: https://www.instagram.com/ynetgram/
# Processing: https://www.youtube.com/channel/UCpSSzrovhI4fA2PQNItecUA
# Processing: https://www.ynet.co.il/news/article/bkvtjapsa
# Processing: https://www.ynet.co.il/news/article/r1x2gero0
# Processing: https://www.ynet.co.il/news/article/sjjmjlro0
# Processing: https://www.ynet.co.il/laisha/article/b1t6wy2jc
# Processing: https://www.ynet.co.il/activism/article/skamxbos0
# Processing: https://www.ynet.co.il/vacation/flights/article/hj4vykcsr
# Processing: https://www.ynet.co.il/parents/article/bkpkh3air
# Processing: https://www.calcalist.co.il/world_news/article/sjqtghtoc
# Processing: https://www.ynet.co.il/entertainment/article/rk700tq7jr
# Processing: https://www.ynet.co.il/architecture/article/h13zpmnsa
# Processing: https://www.ynet.co.il/news/article/byv00oero0
# Processing: https://www.ynet.co.il/news/article/rj4isjaja
# Processing: https://www.ynet.co.il/news/article/hkcffgao0
# Processing: https://www.ynet.co.il/blogs/gazawar328
# Processing: https://www.ynet.co.il/news/article/hkl2r36ic
# Processing: https://www.ynet.co.il/news/article/ryhpwycja
# Processing: https://www.ynet.co.il/news/article/yokra14056938
# Processing: https://www.ynet.co.il/news/article/rk0x7aajc
# Processing: https://www.ynet.co.il/entertainment/article/bkda9sao0
# Processing: https://www.ynet.co.il/entertainment/article/r1aozqajr
# Processing: https://www.ynet.co.il/entertainment/article/yokra14040105
# Processing: https://www.ynet.co.il/entertainment/relevant
# Processing: https://www.ynet.co.il/entertainment/relevant/article/by5d0a6oc
# Processing: https://www.ynet.co.il/entertainment/relevant/article/rkynlkrjc
# Processing: https://www.ynet.co.il/entertainment/relevant/article/hyigw0psc
# Processing: https://pplus.ynet.co.il/royals/article/r1pi9qasr
# Processing: https://pplus.ynet.co.il/rechilut/article/skaogl0oc
# Processing: https://pplus.ynet.co.il/richul/article/bkrfsyro0
# Processing: https://pplus.ynet.co.il/paparazzi/article/sjc48qpic
# Processing: https://pplus.ynet.co.il/paparazzi/article/rykleo3sa
# Processing: https://www.ynet.co.il/environment-science/article/sjdpqwpoc
# Processing: https://www.ynet.co.il/environment-science/article/syqtpi6s0
# Processing: https://www.ynet.co.il/environment-science/article/hkske36sa
# Processing: https://www.ynet.co.il/environment-science/article/s17xtipsc
# Processing: https://www.ynet.co.il/environment-science/article/sybzjz6sc
# Processing: https://www.ynet.co.il/environment-science/article/r1jd8bnja
# Processing: https://www.ynet.co.il/economy/article/skuhho2ic
# Processing: https://www.ynet.co.il/digital/technology/article/s135bd2ja
# Processing: https://www.ynet.co.il/digital/technews/article/r1q0essj0
# Processing: https://www.ynet.co.il/digital/technews/article/hk4m2f5jr
# Processing: https://www.ynet.co.il/digital/article/bj00qimcs0
# Processing: https://www.ynet.co.il/digital/technews/article/syjwjudi0
# Processing: https://www.instagram.com/laishamag/?utm_source=ynet&utm_medium=referral&utm_campaign=social-inks&utm_content=laisha
# Processing: https://www.facebook.com/LaishaMagazine?utm_source=ynet&utm_medium=referral&utm_campaign=social-inks&utm_content=laisha
# Processing: https://www.ynet.co.il/laisha/article/rke2isuir
# Processing: https://www.ynet.co.il/laisha/article/bjwy7800jr
# Processing: https://www.ynet.co.il/activism/article/h1zsfu57r
# Processing: https://www.ynet.co.il/activism/article/h1bcm116t0
# Processing: https://www.ynet.co.il/activism/article/hyzb4zpka
# Processing: https://lastminute.co.il/?utm_source=Ynet&utm_medium=Logo&utm_campaign=banner+
# Processing: https://icar.co.il/news/synk0ytja
# Processing: https://icar.co.il/news/rjahzanjc
# Processing: https://icar.co.il/news/byv8orhj0
# Processing: https://icar.co.il/news/hkuf11onja
# Processing: https://icar.co.il/news/ryqtkhoic
# Processing: https://www.ynet.co.il/judaism/article/r1pnhu6s0
# Processing: https://www.ynet.co.il/judaism/article/bjndwpair
# Processing: https://www.ynet.co.il/judaism/article/r1m94shsc
# Processing: https://www.ynet.co.il/judaism/article/rkbecwjjr
# Processing: https://www.ynet.co.il/judaism/article/hky6xh3i0
# Processing: https://www.ynet.co.il/dating/sexappeal/article/tjvukpbs6
# Processing: https://www.ynet.co.il/dating/couples/article/r1cs2dii0
# Processing: https://www.ynet.co.il/dating/pride/article/peajsiccd
# Processing: https://www.ynet.co.il/vacation/worldtrips/article/rk11cie5sr
# Processing: https://www.ynet.co.il/vacation/flights/article/hku11gtps0
# Processing: https://www.ynet.co.il/food/foodnews/article/bywzph2oa
# Processing: https://www.ynet.co.il/food/article/b1dqizisa
# Processing: https://www.ynet.co.il/food/article/bjrzlmjsc
# Processing: https://www.ynet.co.il/parents/article/rjnih9pjr
# Processing: https://www.ynet.co.il/parents/article/yokra14052047
# Processing: https://www.ynet.co.il/fashion/article/byoyu5pia
# Processing: https://www.ynet.co.il/fashion/article/bjo8fbnor
# Processing: https://www.ynet.co.il/fashion/article/bkldp5eir
# Processing: https://www.ynet.co.il/activism/article/yokra14056622
# Processing: https://www.ynet.co.il/activism/article/yokra14054889
# Processing: https://www.ynet.co.il/activism/article/yokra14054038
# Processing: https://www.ynet.co.il/economy/category/10610
# Processing: https://www.ynet.co.il/economy/article/ryfl99ksc
# Processing: https://www.ynet.co.il/economy/article/hkmzpuior
# Processing: https://www.ynet.co.il/economy/article/bkewoijoc
# Processing: https://www.ynet.co.il/architecture/article/hjhgwmija
# Processing: https://www.ynet.co.il/architecture/article/s10bvldjr
# Processing: https://www.ynet.co.il/economy/remember/article/skf3fpc00a
# Processing: https://www.ynet.co.il/economy/article/r1vzwca8a
# Processing: https://www.frogi.co.il/?utm_source=ynet.co.il&utm_medium=referral&utm_campaign=Header
# Processing: https://www.frogi.co.il/entertainment/tv/47878?utm_source=ynet.co.il&utm_medium=referral&utm_campaign=component&pic=
# Processing: https://www.frogi.co.il/music/local/47875?utm_source=ynet.co.il&utm_medium=referral&utm_campaign=component&pic=
# Processing: https://www.ynet.co.il/health/article/hkcow6aua
# Processing: https://www.ynet.co.il/vacation/article/rktnifqxc
# Processing: https://www.ynet.co.il/parents/article/h1stjp11d0
# Processing: https://www.ynet.co.il/article/rkxuwxtx0
# Processing: https://www.ynet.co.il/laisha/article/b17mlldsa
# Processing: https://www.ynet.co.il/laisha/plus/article/bjdnnthja
# Processing: https://beersheva.mynet.co.il/local_news/article/hjqpicu6sc
# Processing: https://jerusalem.mynet.co.il/local_news/article/bkzbjtoja
# Processing: https://www.ynet.co.il/news/120andone/article/sj8fv03sa
# Processing: https://www.ynet.co.il/news/theheadline/article/8vnnxtxfp
# Processing: https://www.activetrail.co.il/?utm_source=ynet&utm_medium=website&utm_campaign=logo
# Processing: http://www.radware.com/
# Processing: http://www.acum.org.il/
# Processing: http://www.tali-rights.co.il/
# Processing: https://userway.org/?utm_source=ynet.co.il&utm_medium=widget_footer&utm_campaign=widget
# Processing: https://yit.co.il/
# Data successfully saved to 'web_crawl_output_ynet.xlsx'
